# %%
import pandas as pd
import folium
from pyproj import Transformer

# %%
city = 'graz'
stations = pd.read_csv('../data/' + city + '/stations/netatmo_stations.csv', delimiter=',')
stations.head()
# Out:
#            device_id          module_id        lon        lat
# 0  70:ee:50:37:23:aa  02:00:00:36:fd:2e  15.240849  47.046135
# 1  70:ee:50:05:06:58  02:00:00:04:81:7a  15.271094  47.057315
# 2  70:ee:50:7f:a6:ec  02:00:00:7f:a3:62  15.280108  47.060491
# 3  70:ee:50:a5:80:90  02:00:00:a4:2f:5e  15.285259  47.056542
# 4  70:ee:50:28:bc:4c  02:00:00:27:1a:0c  15.282566  47.062895

# %%
stations['lat'].mean()
# Out:
# 47.058775431876114

# %%
coords = (stations['lat'].mean(), stations['lon'].mean())
map = folium.Map(location=coords, zoom_start=13)

# Iterate over each station
for index, station in stations.iterrows():
    lon = station['lon']
    lat = station['lat']

    # Add a marker for the point
    folium.Marker([lat, lon], popup=station['device_id']).add_to(map)

# If running in a Jupyter Notebook, display the map inline
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_aa5ede373ef44e0c5f5eb9cf59d5f82c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_aa5ede373ef44e0c5f5eb9cf59d5f82c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_aa5ede373ef44e0c5f5eb9cf59d5f82c = L.map(
#                 &quot;map_aa5ede373ef44e0c5f5eb9cf59d5f82c&quot;,
#                 {
#                     center: [47.058775431876114, 15.438808573889485],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ddd1970876065c4a75d4d8eeb7218a50 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_aa5ede373ef44e0c5f5eb9cf59d5f82c);
#
#
#             var marker_5c254fff1251ccc7326c938dc56051e6 = L.marker(
#                 [47.046135, 15.240849],
#                 {}
#             ).addTo(map_aa5ede373ef44e0c5f5eb9cf59d5f82c);
#
#
#         var popup_9e2138c27339e62a74d07828e6c1e238 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7fc69047b3e096d686c04c9a8ce970c = $(`&lt;div id=&quot;html_e7fc69047b3e096d686c04c9a8ce970c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:37:23:aa&lt;/div&gt;`)[0];
#                 popup_9e2138c27339e62a74d07828e6c1e238.setContent(html_e7fc69047b3e096d686c04c9a8ce970c);
#
#
#
#         marker_5c254fff1251ccc7326c938dc56051e6.bindPopup(popup_9e2138c27339e62a74d07828e6c1e238)
#         ;
#
#
#
#
#             var marker_284cc11b5c28ddc7db50c4b0f5ebbd11 = L.marker(
#                 [47.0573148446784, 15.271094384995],
#                 {}
#             ).addTo(map_aa5ede373ef44e0c5f5eb9cf59d5f82c);
#
#
#         var popup_cd68fb3336b6c89d4154e3c45e19efd4 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_8b9850cbd297bd8ec498e7b786effbad = $(`&lt;div id=&quot;html_8b9850cbd297bd8ec498e7b786effbad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:05:06:58&lt;/div&gt;`)[0];
#                 popup_cd68fb3336b6c89d4154e3c45e19efd4.setContent(html_8b9850cbd297bd8ec498e7b786effbad);
#
#
#
#         marker_284cc11b5c28ddc7db50c4b0f5ebbd11.bindPopup(popup_cd68fb3336b6c89d4154e3c45e19efd4)
#         ;
#
#
#
#
#             var marker_754bce7abd3c7bab5c7770df07e1d212 = L.marker(
#                 [47.060491, 15.280108],
#                 {}
#             ).addTo(map_aa5ede373ef44e0c5f5eb9cf59d5f82c);
#
#
#         var popup_84a813fc9fd266d24fc8f1768fc1f360 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e91a0fe8cb0249ce24ae26918b38b1dc = $(`&lt;div id=&quot;html_e91a0fe8cb0249ce24ae26918b38b1dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:7f:a6:ec&lt;/div&gt;`)[0];
#                 popup_84a813fc9fd266d24fc8f1768fc1f360.setContent(html_e91a0fe8cb0249ce24ae26918b38b1dc);
#
#
#
#         marker_754bce7abd3c7bab5c7770df07e1d212.bindPopup(popup_84a813fc9fd266d24fc8f1768fc1f360)
#         ;
#
#
#
#
#             var marker_d94f2a04b6933300a3714377635a8037 = L.marker(
#                 [47.0565421, 15.2852586],
#                 {}
#             ).addTo(map_aa5ede373ef44e0c5f5eb9cf59d5f82c);
#
#
#         var popup_49ba5a93e1a98f1a34bb2625886274b9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5bf31a3eebcde7186ddb6d2b80f19324 = $(`&lt;div id=&quot;html_5bf31a3eebcde7186ddb6d2b80f19324&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:a5:80:90&lt;/div&gt;`)[0];
#                 popup_49ba5a93e1a98f1a34bb2625886274b9.setContent(html_5bf31a3eebcde7186ddb6d2b80f19324);
#
#
#
#         marker_d94f2a04b6933300a3714377635a8037.bindPopup(popup_49ba5a93e1a98f1a34bb2625886274b9)
#         ;
#
#
#
#
#             var marker_21f359c5c3a637baa63490f8300d4fff = L.marker(
#                 [47.062895, 15.282566],
#                 {}
#             ).addTo(map_aa5ede373ef44e0c5f5eb9cf59d5f82c);
#
#
#         var popup_d5e400ad7c13f8e1b3193ae21d96b0a0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3ef2d0e5eca1f9978f0f5ce641d192e0 = $(`&lt;div id=&quot;html_3ef2d0e5eca1f9978f0f5ce641d192e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:28:bc:4c&lt;/div&gt;`)[0];
#                 popup_d5e400ad7c13f8e1b3193ae21d96b0a0.setContent(html_3ef2d0e5eca1f9978f0f5ce641d192e0);
#
#
#
#         marker_21f359c5c3a637baa63490f8300d4fff.bindPopup(popup_d5e400ad7c13f8e1b3193ae21d96b0a0)
#         ;
#
#
#
#
#             var marker_e59433844b47cf005e1d77b64354940c = L.marker(

# %%
selected_stations = [
    '70:ee:50:3b:f5:64', # Venta del Olivar
    '70:ee:50:74:29:4c', # Cuarte de Huerva, Urbanización de Amelia
    '70:ee:50:7a:d1:ce', # Cuarte de Huerva, Urbanización de Amelia
    '70:ee:50:84:81:46', # Murallas de Santa Fe
    '70:ee:50:3f:63:68', # Santa Isabel
    '70:ee:50:2b:58:c2' # Villamayor de Gállego
]

# %% [markdown]
# ### Generate shapefile

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(stations['lon'], stations['lat'])]
gdf = gpd.GeoDataFrame(stations, geometry=geometry)

# Set CRS and save
filename = '../data/' + city + '/shapefiles/netatmo_stations.shp'
gdf.set_crs(epsg=4326, inplace=True)
gdf = gdf.to_crs('EPSG:4326')
gdf.to_file(filename)

# %% [markdown]
# ### Locate stations

# %%
station_id = '70:ee:50:7a:8d:66'

row = stations[stations['device_id'] == station_id]

# Extract lon and lat
lon, lat = row[['lon', 'lat']].values[0]

location_map = folium.Map(location=zgz_coords, zoom_start=13)
folium.Marker([lat, lon], popup=station_id).add_to(location_map)
location_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bc38e584a3bcdf791a6e32603a1b994 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bc38e584a3bcdf791a6e32603a1b994&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bc38e584a3bcdf791a6e32603a1b994 = L.map(
#                 &quot;map_0bc38e584a3bcdf791a6e32603a1b994&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41e2c2abb5266ffcad756090397e95dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0bc38e584a3bcdf791a6e32603a1b994);
#
#
#             var marker_4bbe0ed3e889b3267a2f5ca937dde30f = L.marker(
#                 [41.636124, -0.7481712],
#                 {}
#             ).addTo(map_0bc38e584a3bcdf791a6e32603a1b994);
#
#
#         var popup_0cd2de32c2339aa34790e0af6ac8fcac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca1d24f6159eaf6ed73a25a9d2b7d2d9 = $(`&lt;div id=&quot;html_ca1d24f6159eaf6ed73a25a9d2b7d2d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:7a:8d:66&lt;/div&gt;`)[0];
#                 popup_0cd2de32c2339aa34790e0af6ac8fcac.setContent(html_ca1d24f6159eaf6ed73a25a9d2b7d2d9);
#
#
#
#         marker_4bbe0ed3e889b3267a2f5ca937dde30f.bindPopup(popup_0cd2de32c2339aa34790e0af6ac8fcac)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

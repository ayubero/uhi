# %%
import pandas as pd
import folium
from pyproj import Transformer

# %%
stations = pd.read_csv('netatmo_stations.csv', delimiter=',')
stations.head()
# Out:
#            device_id          module_id       lon        lat
# 0  70:ee:50:af:48:36  02:00:00:af:97:b6 -5.821514  43.380573
# 1  70:ee:50:12:ce:a6  02:00:00:12:ba:e6 -5.821986  43.381939
# 2  70:ee:50:a2:20:c2  02:00:00:a2:03:0c -5.816930  43.378882
# 3  70:ee:50:71:49:30  02:00:00:71:4b:f2 -5.811817  43.377968
# 4  70:ee:50:90:d8:82  02:00:00:ab:de:78 -5.804601  43.379862

# %%
zgz_coords = (41.653858, -0.876258)
map = folium.Map(location=zgz_coords, zoom_start=13)

# Iterate over each station
for index, station in stations.iterrows():
    lon = station['lon']
    lat = station['lat']

    # Add a marker for the point
    folium.Marker([lat, lon], popup=station['device_id']).add_to(map)

# If running in a Jupyter Notebook, display the map inline
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_517c6dad55e4a0ce997823be9639b322 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_517c6dad55e4a0ce997823be9639b322&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_517c6dad55e4a0ce997823be9639b322 = L.map(
#                 &quot;map_517c6dad55e4a0ce997823be9639b322&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f59505b0f49e98c48741d874ba62910 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_517c6dad55e4a0ce997823be9639b322);
#
#
#             var marker_239dc884d24b9e06c9d21153ea64a6bd = L.marker(
#                 [43.3805732727051, -5.82151365280151],
#                 {}
#             ).addTo(map_517c6dad55e4a0ce997823be9639b322);
#
#
#         var popup_a05c2da5147f9fc0e9518e860d50c872 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_823109d4e11de66d39200edc39565d94 = $(`&lt;div id=&quot;html_823109d4e11de66d39200edc39565d94&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:af:48:36&lt;/div&gt;`)[0];
#                 popup_a05c2da5147f9fc0e9518e860d50c872.setContent(html_823109d4e11de66d39200edc39565d94);
#
#
#
#         marker_239dc884d24b9e06c9d21153ea64a6bd.bindPopup(popup_a05c2da5147f9fc0e9518e860d50c872)
#         ;
#
#
#
#
#             var marker_7356ec8c5eef34e10453f3919dd2974e = L.marker(
#                 [43.3819389343262, -5.82198619842529],
#                 {}
#             ).addTo(map_517c6dad55e4a0ce997823be9639b322);
#
#
#         var popup_15ab552fa0df058cd9bc85f87f780f4a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7fb1116347b3bf7c3c56068cc2ee45cb = $(`&lt;div id=&quot;html_7fb1116347b3bf7c3c56068cc2ee45cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:12:ce:a6&lt;/div&gt;`)[0];
#                 popup_15ab552fa0df058cd9bc85f87f780f4a.setContent(html_7fb1116347b3bf7c3c56068cc2ee45cb);
#
#
#
#         marker_7356ec8c5eef34e10453f3919dd2974e.bindPopup(popup_15ab552fa0df058cd9bc85f87f780f4a)
#         ;
#
#
#
#
#             var marker_176be52d7c518f762cb2523d315fd3fd = L.marker(
#                 [43.3788823763479, -5.81692995438971],
#                 {}
#             ).addTo(map_517c6dad55e4a0ce997823be9639b322);
#
#
#         var popup_d0784f5b64100adaf77c0364f8a61b77 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2d942941eea76802bb39737e5a9fcf6e = $(`&lt;div id=&quot;html_2d942941eea76802bb39737e5a9fcf6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:a2:20:c2&lt;/div&gt;`)[0];
#                 popup_d0784f5b64100adaf77c0364f8a61b77.setContent(html_2d942941eea76802bb39737e5a9fcf6e);
#
#
#
#         marker_176be52d7c518f762cb2523d315fd3fd.bindPopup(popup_d0784f5b64100adaf77c0364f8a61b77)
#         ;
#
#
#
#
#             var marker_1faad2c05ab571b78fd138374714afdf = L.marker(
#                 [43.377968, -5.8118167],
#                 {}
#             ).addTo(map_517c6dad55e4a0ce997823be9639b322);
#
#
#         var popup_b2e06cc1692526e3e0fb509e4c9b49fa = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37e92c051e4667e5bf7dcfebd412d6a3 = $(`&lt;div id=&quot;html_37e92c051e4667e5bf7dcfebd412d6a3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:71:49:30&lt;/div&gt;`)[0];
#                 popup_b2e06cc1692526e3e0fb509e4c9b49fa.setContent(html_37e92c051e4667e5bf7dcfebd412d6a3);
#
#
#
#         marker_1faad2c05ab571b78fd138374714afdf.bindPopup(popup_b2e06cc1692526e3e0fb509e4c9b49fa)
#         ;
#
#
#
#
#             var marker_5294931dafd94f12672155fd96c5806a = L.marker(
#                 [43.379862, -5.804601],
#                 {}
#             ).addTo(map_517c6dad55e4a0ce997823be9639b322);
#
#
#         var popup_88d5e18ef261c80a93a29eb69de2cf58 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_06701974ca24cd5a0c03d71d37991bce = $(`&lt;div id=&quot;html_06701974ca24cd5a0c03d71d37991bce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:90:d8:82&lt;/div&gt;`)[0];
#                 popup_88d5e18ef261c80a93a29eb69de2cf58.setContent(html_06701974ca24cd5a0c03d71d37991bce);
#
#
#
#         marker_5294931dafd94f12672155fd96c5806a.bindPopup(popup_88d5e18ef261c80a93a29eb69de2cf58)
#         ;
#
#
#
#
#             var marker_311d0562511a8372ac8f0db3656fa771 =

# %%
'''ref_stations = [
    '70:ee:50:2b:5b:da', # Villamar
    '70:ee:50:5e:f5:44'
]'''
# Out:
# "ref_stations = [\n    '70:ee:50:2b:5b:da', # Villamar\n    '70:ee:50:5e:f5:44'\n]"

# %% [markdown]
# ### Generate shapefile

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(stations['lon'], stations['lat'])]
gdf = gpd.GeoDataFrame(stations, geometry=geometry)

# Set CRS and save
filename = 'netatmo_stations.shp'
gdf.set_crs(epsg=4326, inplace=True)
gdf = gdf.to_crs('EPSG:25830')
gdf.to_file(filename)

# %% [markdown]
# ### Locate stations

# %%
station_id = '70:ee:50:2b:5b:da'

row = stations[stations['device_id'] == station_id]

# Extract lon and lat
lon, lat = row[['lon', 'lat']].values[0]

location_map = folium.Map(location=zgz_coords, zoom_start=13)
folium.Marker([lat, lon], popup=station_id).add_to(location_map)
location_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_97eee3297c1816b0aadb40eabc510e86 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_97eee3297c1816b0aadb40eabc510e86&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_97eee3297c1816b0aadb40eabc510e86 = L.map(
#                 &quot;map_97eee3297c1816b0aadb40eabc510e86&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9c9d49a4f1c2233b8e501570f84d90b7 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_97eee3297c1816b0aadb40eabc510e86);
#
#
#             var marker_318d02d9aec4a28e4bba5cf0aff80bb9 = L.marker(
#                 [43.37062, -5.8996196],
#                 {}
#             ).addTo(map_97eee3297c1816b0aadb40eabc510e86);
#
#
#         var popup_f0f84621caceb71d426d79f2724acf63 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_1dafe15843ec31eda5a8c1e70f234dd8 = $(`&lt;div id=&quot;html_1dafe15843ec31eda5a8c1e70f234dd8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:2b:5b:da&lt;/div&gt;`)[0];
#                 popup_f0f84621caceb71d426d79f2724acf63.setContent(html_1dafe15843ec31eda5a8c1e70f234dd8);
#
#
#
#         marker_318d02d9aec4a28e4bba5cf0aff80bb9.bindPopup(popup_f0f84621caceb71d426d79f2724acf63)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

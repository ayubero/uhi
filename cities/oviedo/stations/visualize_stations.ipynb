# %%
import pandas as pd
import folium
from pyproj import Transformer

# %%
stations = pd.read_csv('netatmo_stations.csv', delimiter=',')
stations.head()
# Out:
#            device_id          module_id       lon        lat
# 0  70:ee:50:af:48:36  02:00:00:af:97:b6 -5.821514  43.380573
# 1  70:ee:50:12:ce:a6  02:00:00:12:ba:e6 -5.821986  43.381939
# 2  70:ee:50:a2:20:c2  02:00:00:a2:03:0c -5.816930  43.378882
# 3  70:ee:50:71:49:30  02:00:00:71:4b:f2 -5.811817  43.377968
# 4  70:ee:50:90:d8:82  02:00:00:ab:de:78 -5.804601  43.379862

# %%
zgz_coords = (41.653858, -0.876258)
map = folium.Map(location=zgz_coords, zoom_start=13)

# Iterate over each station
for index, station in stations.iterrows():
    lon = station['lon']
    lat = station['lat']

    # Add a marker for the point
    folium.Marker([lat, lon], popup=station['device_id']).add_to(map)

# If running in a Jupyter Notebook, display the map inline
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d52637ba50a3bca8fd53ec4658de51dd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d52637ba50a3bca8fd53ec4658de51dd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d52637ba50a3bca8fd53ec4658de51dd = L.map(
#                 &quot;map_d52637ba50a3bca8fd53ec4658de51dd&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7e5a4f01659cadf09878438fb74395eb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d52637ba50a3bca8fd53ec4658de51dd);
#
#
#             var marker_2fa473a6250cb5221cff2b512c0b777c = L.marker(
#                 [43.3805732727051, -5.82151365280151],
#                 {}
#             ).addTo(map_d52637ba50a3bca8fd53ec4658de51dd);
#
#
#         var popup_7cb4a05ae6b1615ca6d7f3bd0f706057 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7697ff1bb9c983758c7e5011b84adcb = $(`&lt;div id=&quot;html_d7697ff1bb9c983758c7e5011b84adcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:af:48:36&lt;/div&gt;`)[0];
#                 popup_7cb4a05ae6b1615ca6d7f3bd0f706057.setContent(html_d7697ff1bb9c983758c7e5011b84adcb);
#
#
#
#         marker_2fa473a6250cb5221cff2b512c0b777c.bindPopup(popup_7cb4a05ae6b1615ca6d7f3bd0f706057)
#         ;
#
#
#
#
#             var marker_681d733012e75d09f17f0fadf4cb78cf = L.marker(
#                 [43.3819389343262, -5.82198619842529],
#                 {}
#             ).addTo(map_d52637ba50a3bca8fd53ec4658de51dd);
#
#
#         var popup_c1f1680484d50743e0425ffcfcca170b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_fcaea80f9736b55a3632e86fd3f33e98 = $(`&lt;div id=&quot;html_fcaea80f9736b55a3632e86fd3f33e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:12:ce:a6&lt;/div&gt;`)[0];
#                 popup_c1f1680484d50743e0425ffcfcca170b.setContent(html_fcaea80f9736b55a3632e86fd3f33e98);
#
#
#
#         marker_681d733012e75d09f17f0fadf4cb78cf.bindPopup(popup_c1f1680484d50743e0425ffcfcca170b)
#         ;
#
#
#
#
#             var marker_af8e8f8413f3113f59482d2911ea912e = L.marker(
#                 [43.3788823763479, -5.81692995438971],
#                 {}
#             ).addTo(map_d52637ba50a3bca8fd53ec4658de51dd);
#
#
#         var popup_94a46c1c802ca0220982d8e9eba7380d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f0e9156dbdf32edd7c544862a568a277 = $(`&lt;div id=&quot;html_f0e9156dbdf32edd7c544862a568a277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:a2:20:c2&lt;/div&gt;`)[0];
#                 popup_94a46c1c802ca0220982d8e9eba7380d.setContent(html_f0e9156dbdf32edd7c544862a568a277);
#
#
#
#         marker_af8e8f8413f3113f59482d2911ea912e.bindPopup(popup_94a46c1c802ca0220982d8e9eba7380d)
#         ;
#
#
#
#
#             var marker_475c1f1285ad9d42d0bab6d14be8be9e = L.marker(
#                 [43.377968, -5.8118167],
#                 {}
#             ).addTo(map_d52637ba50a3bca8fd53ec4658de51dd);
#
#
#         var popup_48a9acabcfa64b0f211d3fd862934319 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b6a063787faaf0ae6f29869b2eba5676 = $(`&lt;div id=&quot;html_b6a063787faaf0ae6f29869b2eba5676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:71:49:30&lt;/div&gt;`)[0];
#                 popup_48a9acabcfa64b0f211d3fd862934319.setContent(html_b6a063787faaf0ae6f29869b2eba5676);
#
#
#
#         marker_475c1f1285ad9d42d0bab6d14be8be9e.bindPopup(popup_48a9acabcfa64b0f211d3fd862934319)
#         ;
#
#
#
#
#             var marker_74bfdae90ae74c1277c040e40e58f25a = L.marker(
#                 [43.379862, -5.804601],
#                 {}
#             ).addTo(map_d52637ba50a3bca8fd53ec4658de51dd);
#
#
#         var popup_ef5a4dc0a542eeb6966f4c6b7552aa06 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_f6d55eb00513488b334cc4384609ff2a = $(`&lt;div id=&quot;html_f6d55eb00513488b334cc4384609ff2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:90:d8:82&lt;/div&gt;`)[0];
#                 popup_ef5a4dc0a542eeb6966f4c6b7552aa06.setContent(html_f6d55eb00513488b334cc4384609ff2a);
#
#
#
#         marker_74bfdae90ae74c1277c040e40e58f25a.bindPopup(popup_ef5a4dc0a542eeb6966f4c6b7552aa06)
#         ;
#
#
#
#
#             var marker_f353f0c26c247dd53650a3b508bcf31e =

# %%
'''stations = [
    '70:ee:50:7a:c2:72', # Camino de Sanlúcar
    '70:ee:50:71:59:b0', # La Motilla
    '70:ee:50:73:e2:d8', # Dos Hermanas
    '70:ee:50:04:a4:52', # San José de la Rinconada 1
    '70:ee:50:7f:a6:e0', # San José de la Rinconada 2
    '70:ee:50:32:ae:72', # Coria del Río
    '70:ee:50:06:91:04', # La Puebla del Río
    '70:ee:50:65:37:e0', # Almensilla
]'''
# Out:
# "stations = [\n    '70:ee:50:7a:c2:72', # Camino de Sanlúcar\n    '70:ee:50:71:59:b0', # La Motilla\n    '70:ee:50:73:e2:d8', # Dos Hermanas\n    '70:ee:50:04:a4:52', # San José de la Rinconada 1\n    '70:ee:50:7f:a6:e0', # San José de la Rinconada 2\n    '70:ee:50:32:ae:72', # Coria del Río\n    '70:ee:50:06:91:04', # La Puebla del Río\n    '70:ee:50:65:37:e0', # Almensilla\n]"

# %% [markdown]
# ### Generate shapefile

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(stations['lon'], stations['lat'])]
gdf = gpd.GeoDataFrame(stations, geometry=geometry)

# Set CRS and save
filename = 'netatmo_stations.shp'
gdf.set_crs(epsg=4326, inplace=True)
gdf = gdf.to_crs('EPSG:25830')
gdf.to_file(filename)

# %% [markdown]
# ### Locate stations

# %%
station_id = '70:ee:50:65:37:e0'

row = stations[stations['device_id'] == station_id]

# Extract lon and lat
lon, lat = row[['lon', 'lat']].values[0]

location_map = folium.Map(location=zgz_coords, zoom_start=13)
folium.Marker([lat, lon], popup=station_id).add_to(location_map)
location_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_baae62c74b42d404b20793298be6083e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_baae62c74b42d404b20793298be6083e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_baae62c74b42d404b20793298be6083e = L.map(
#                 &quot;map_baae62c74b42d404b20793298be6083e&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_25fbb37a60761d044015f3d21a1e220c = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_baae62c74b42d404b20793298be6083e);
#
#
#             var marker_9f5655e37cc1eb04b62bc3f725b98249 = L.marker(
#                 [37.312434, -6.105685],
#                 {}
#             ).addTo(map_baae62c74b42d404b20793298be6083e);
#
#
#         var popup_9517331706af5ff4145b3aae27001df0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7c293705a47e34119673d9889956fbb8 = $(`&lt;div id=&quot;html_7c293705a47e34119673d9889956fbb8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:65:37:e0&lt;/div&gt;`)[0];
#                 popup_9517331706af5ff4145b3aae27001df0.setContent(html_7c293705a47e34119673d9889956fbb8);
#
#
#
#         marker_9f5655e37cc1eb04b62bc3f725b98249.bindPopup(popup_9517331706af5ff4145b3aae27001df0)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
import folium
from pyproj import Transformer

# %%
stations = pd.read_csv('netatmo_stations.csv', delimiter=',')
stations.head()
# Out:
#            device_id          module_id       lon        lat
# 0  70:ee:50:17:e9:26  02:00:00:17:e2:aa -0.472264  39.260814
# 1  70:ee:50:6b:35:64  02:00:00:6b:78:60 -0.472086  39.264747
# 2  70:ee:50:3c:dd:7e  02:00:00:3c:fb:52 -0.467302  39.260201
# 3  70:ee:50:a4:63:6e  02:00:00:a4:1c:50 -0.416428  39.292213
# 4  70:ee:50:84:95:f6  02:00:00:84:7c:38 -0.290545  39.303333

# %%
zgz_coords = (41.653858, -0.876258)
map = folium.Map(location=zgz_coords, zoom_start=13)

# Iterate over each station
for index, station in stations.iterrows():
    lon = station['lon']
    lat = station['lat']

    # Add a marker for the point
    folium.Marker([lat, lon], popup=station['device_id']).add_to(map)

# If running in a Jupyter Notebook, display the map inline
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_13c0254d2c3f1919f6c187027997da8a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_13c0254d2c3f1919f6c187027997da8a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_13c0254d2c3f1919f6c187027997da8a = L.map(
#                 &quot;map_13c0254d2c3f1919f6c187027997da8a&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa1aff93d537f250f0c657ee38085b09 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_13c0254d2c3f1919f6c187027997da8a);
#
#
#             var marker_b045432743e0c36c6123497c1a58900d = L.marker(
#                 [39.260814, -0.472264],
#                 {}
#             ).addTo(map_13c0254d2c3f1919f6c187027997da8a);
#
#
#         var popup_f5fa2c4666f77545ba39a272f997aebb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e885c2fff815abeacbe99d1982edb451 = $(`&lt;div id=&quot;html_e885c2fff815abeacbe99d1982edb451&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:17:e9:26&lt;/div&gt;`)[0];
#                 popup_f5fa2c4666f77545ba39a272f997aebb.setContent(html_e885c2fff815abeacbe99d1982edb451);
#
#
#
#         marker_b045432743e0c36c6123497c1a58900d.bindPopup(popup_f5fa2c4666f77545ba39a272f997aebb)
#         ;
#
#
#
#
#             var marker_ba16cfb627f3609415a0157986de7d92 = L.marker(
#                 [39.2647472187732, -0.472085772000836],
#                 {}
#             ).addTo(map_13c0254d2c3f1919f6c187027997da8a);
#
#
#         var popup_e16c13eb2eb6fd0e30865daa45bd74e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eacf5fee56a25618e15cfdd081dc52d2 = $(`&lt;div id=&quot;html_eacf5fee56a25618e15cfdd081dc52d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:6b:35:64&lt;/div&gt;`)[0];
#                 popup_e16c13eb2eb6fd0e30865daa45bd74e1.setContent(html_eacf5fee56a25618e15cfdd081dc52d2);
#
#
#
#         marker_ba16cfb627f3609415a0157986de7d92.bindPopup(popup_e16c13eb2eb6fd0e30865daa45bd74e1)
#         ;
#
#
#
#
#             var marker_12bf5c1a5edeaed4a0950f6378f8d835 = L.marker(
#                 [39.2602005004883, -0.467302352190018],
#                 {}
#             ).addTo(map_13c0254d2c3f1919f6c187027997da8a);
#
#
#         var popup_6db836b7dbe805db39e910629caee665 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2fbdf7eb9948cee186e28a21dc736670 = $(`&lt;div id=&quot;html_2fbdf7eb9948cee186e28a21dc736670&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:3c:dd:7e&lt;/div&gt;`)[0];
#                 popup_6db836b7dbe805db39e910629caee665.setContent(html_2fbdf7eb9948cee186e28a21dc736670);
#
#
#
#         marker_12bf5c1a5edeaed4a0950f6378f8d835.bindPopup(popup_6db836b7dbe805db39e910629caee665)
#         ;
#
#
#
#
#             var marker_104e4d6e97a31533fea688eae96b8be5 = L.marker(
#                 [39.2922134399414, -0.416427582502365],
#                 {}
#             ).addTo(map_13c0254d2c3f1919f6c187027997da8a);
#
#
#         var popup_d10fc176e6b7ce7618189a5adac95fd6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a0282ebea53eddae7ac076d10f124919 = $(`&lt;div id=&quot;html_a0282ebea53eddae7ac076d10f124919&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:a4:63:6e&lt;/div&gt;`)[0];
#                 popup_d10fc176e6b7ce7618189a5adac95fd6.setContent(html_a0282ebea53eddae7ac076d10f124919);
#
#
#
#         marker_104e4d6e97a31533fea688eae96b8be5.bindPopup(popup_d10fc176e6b7ce7618189a5adac95fd6)
#         ;
#
#
#
#
#             var marker_ff080418f858f06d7a08cf8ef1df1e4f = L.marker(
#                 [39.3033332824707, -0.290544807910919],
#                 {}
#             ).addTo(map_13c0254d2c3f1919f6c187027997da8a);
#
#
#         var popup_7492eebd3ff6ba20e21b2bc2075bd7ea = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a7a0e3dbe2a8330fe06d9e890c0d1f09 = $(`&lt;div id=&quot;html_a7a0e3dbe2a8330fe06d9e890c0d1f09&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:84:95:f6&lt;/div&gt;`)[0];
#                 popup_7492eebd3ff6ba20e21b2bc2075bd7ea.setContent(html_a7a0e3dbe2a8330fe06d9e890c0d1f09);
#
#
#
#         marker_ff080418f858f06d7a08cf8ef1df1e4f.bindPopup(popup_7492eebd3ff6ba20e21b2bc2075bd7ea)
#         ;
#
#
#
#
#             var marker_d07065c90b1570d01

# %%
'''ref_stations = [
    '70:ee:50:96:b5:46', # Xalets de Lladró
    '70:ee:50:7f:f2:14', # Bungalows Park Albufera
    '70:ee:50:17:9c:76', # Urbanització El Pedregal
    '70:ee:50:74:27:1a', # Urbanització Monte Rosado
    '70:ee:50:19:22:84'  # Serra Perenxisa
]'''
# Out:
# "ref_stations = [\n    '70:ee:50:96:b5:46', # Xalets de Lladró\n    '70:ee:50:17:9c:76', # Urbanització El Pedregal\n    '70:ee:50:74:27:1a', # Urbanització Monte Rosado\n    '70:ee:50:7f:f2:14', # Bungalows Park Albufera\n    '70:ee:50:19:22:84'  # Serra Perenxisa\n]"

# %% [markdown]
# ### Generate shapefile

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(stations['lon'], stations['lat'])]
gdf = gpd.GeoDataFrame(stations, geometry=geometry)

# Set CRS and save
filename = 'netatmo_stations.shp'
gdf.set_crs(epsg=4326, inplace=True)
gdf = gdf.to_crs('EPSG:25830')
gdf.to_file(filename)

# %% [markdown]
# ### Locate stations

# %%
station_id = '70:ee:50:19:22:84'

row = stations[stations['device_id'] == station_id]

# Extract lon and lat
lon, lat = row[['lon', 'lat']].values[0]

location_map = folium.Map(location=zgz_coords, zoom_start=13)
folium.Marker([lat, lon], popup=station_id).add_to(location_map)
location_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_048a1edf5bf2d61b05e1546f8f27eded {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_048a1edf5bf2d61b05e1546f8f27eded&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_048a1edf5bf2d61b05e1546f8f27eded = L.map(
#                 &quot;map_048a1edf5bf2d61b05e1546f8f27eded&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ee89d93a26a7ba1ae90aeb6b0545640b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_048a1edf5bf2d61b05e1546f8f27eded);
#
#
#             var marker_bc9a0fde37f0fc405a5a56e8dafd7451 = L.marker(
#                 [39.4335562998512, -0.603184945456974],
#                 {}
#             ).addTo(map_048a1edf5bf2d61b05e1546f8f27eded);
#
#
#         var popup_3c02ff450fe4c4af015bb6a40525746d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_37955699389c4b04fa09ef03fe73b5c3 = $(`&lt;div id=&quot;html_37955699389c4b04fa09ef03fe73b5c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:19:22:84&lt;/div&gt;`)[0];
#                 popup_3c02ff450fe4c4af015bb6a40525746d.setContent(html_37955699389c4b04fa09ef03fe73b5c3);
#
#
#
#         marker_bc9a0fde37f0fc405a5a56e8dafd7451.bindPopup(popup_3c02ff450fe4c4af015bb6a40525746d)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

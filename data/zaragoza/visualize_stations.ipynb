# %%
import pandas as pd
import folium
from pyproj import Transformer

# %%
stations = pd.read_csv('netatmo_stations.csv', delimiter=',')
stations.head()
# Out:
#            device_id          module_id       lon        lat
# 0  70:ee:50:7a:8d:66  02:00:00:7a:82:20 -0.748171  41.636124
# 1  70:ee:50:3f:63:68  02:00:00:3e:e0:04 -0.833446  41.671643
# 2  70:ee:50:3f:18:7e  02:00:00:3c:ec:c0 -0.774684  41.685630
# 3  70:ee:50:2b:58:c2  02:00:00:2a:db:82 -0.803851  41.712556
# 4  70:ee:50:36:cf:1c  02:00:00:37:03:a4 -0.797466  41.743163

# %%
zgz_coords = (41.653858, -0.876258)
map = folium.Map(location=zgz_coords, zoom_start=13)

# Iterate over each station
for index, station in stations.iterrows():
    lon = station['lon']
    lat = station['lat']

    # Add a marker for the point
    folium.Marker([lat, lon], popup=station['device_id']).add_to(map)

# If running in a Jupyter Notebook, display the map inline
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_767be3e00255ea8db3ecb5300308b07c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_767be3e00255ea8db3ecb5300308b07c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_767be3e00255ea8db3ecb5300308b07c = L.map(
#                 &quot;map_767be3e00255ea8db3ecb5300308b07c&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_28c3c610be21c20dd82f21fb03ff66bc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_767be3e00255ea8db3ecb5300308b07c);
#
#
#             var marker_e3c860bd79add3dee34192393e9b6596 = L.marker(
#                 [41.636124, -0.7481712],
#                 {}
#             ).addTo(map_767be3e00255ea8db3ecb5300308b07c);
#
#
#         var popup_4a903ca63da76d1b4c34effced852803 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4ef1d18628d062ce02e11439bb3b349c = $(`&lt;div id=&quot;html_4ef1d18628d062ce02e11439bb3b349c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:7a:8d:66&lt;/div&gt;`)[0];
#                 popup_4a903ca63da76d1b4c34effced852803.setContent(html_4ef1d18628d062ce02e11439bb3b349c);
#
#
#
#         marker_e3c860bd79add3dee34192393e9b6596.bindPopup(popup_4a903ca63da76d1b4c34effced852803)
#         ;
#
#
#
#
#             var marker_2dba54c7dcd8d59a6845aa10e7112492 = L.marker(
#                 [41.6716431569669, -0.833446027880559],
#                 {}
#             ).addTo(map_767be3e00255ea8db3ecb5300308b07c);
#
#
#         var popup_19a4e4d76c39699d38689f765c196c1a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3291dec046ccf733cffa08f21a07a6be = $(`&lt;div id=&quot;html_3291dec046ccf733cffa08f21a07a6be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:3f:63:68&lt;/div&gt;`)[0];
#                 popup_19a4e4d76c39699d38689f765c196c1a.setContent(html_3291dec046ccf733cffa08f21a07a6be);
#
#
#
#         marker_2dba54c7dcd8d59a6845aa10e7112492.bindPopup(popup_19a4e4d76c39699d38689f765c196c1a)
#         ;
#
#
#
#
#             var marker_1c8b25114bae9cc03983dd64a399d8c5 = L.marker(
#                 [41.6856299, -0.774684],
#                 {}
#             ).addTo(map_767be3e00255ea8db3ecb5300308b07c);
#
#
#         var popup_3fcaa56aa775bffd60bc3b2344a8ae85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a1bb0ad3040ee3accd164d62c293375d = $(`&lt;div id=&quot;html_a1bb0ad3040ee3accd164d62c293375d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:3f:18:7e&lt;/div&gt;`)[0];
#                 popup_3fcaa56aa775bffd60bc3b2344a8ae85.setContent(html_a1bb0ad3040ee3accd164d62c293375d);
#
#
#
#         marker_1c8b25114bae9cc03983dd64a399d8c5.bindPopup(popup_3fcaa56aa775bffd60bc3b2344a8ae85)
#         ;
#
#
#
#
#             var marker_dceae7273d28ba9507e3c56cafa8ff3e = L.marker(
#                 [41.7125558277646, -0.80385139106744],
#                 {}
#             ).addTo(map_767be3e00255ea8db3ecb5300308b07c);
#
#
#         var popup_8ffa1a34a0d7254fed67801b2f183c41 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_0f08837feb166351c6ba1708e3cd9f0d = $(`&lt;div id=&quot;html_0f08837feb166351c6ba1708e3cd9f0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:2b:58:c2&lt;/div&gt;`)[0];
#                 popup_8ffa1a34a0d7254fed67801b2f183c41.setContent(html_0f08837feb166351c6ba1708e3cd9f0d);
#
#
#
#         marker_dceae7273d28ba9507e3c56cafa8ff3e.bindPopup(popup_8ffa1a34a0d7254fed67801b2f183c41)
#         ;
#
#
#
#
#             var marker_1b05094cd06cc3f2cc1fe9325b483c76 = L.marker(
#                 [41.743163, -0.797466],
#                 {}
#             ).addTo(map_767be3e00255ea8db3ecb5300308b07c);
#
#
#         var popup_205787d0771a7cbd7d6495021390208d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b32450687c8e50aaa16a0e14474ce180 = $(`&lt;div id=&quot;html_b32450687c8e50aaa16a0e14474ce180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:36:cf:1c&lt;/div&gt;`)[0];
#                 popup_205787d0771a7cbd7d6495021390208d.setContent(html_b32450687c8e50aaa16a0e14474ce180);
#
#
#
#         marker_1b05094cd06cc3f2cc1fe9325b483c76.bindPopup(popup_205787d0771a7cbd7d6495021390208d)
#         ;
#
#
#
#
#             var marker_0a2208e16ae2eda4ed5e204828022b03 = L.marker(

# %%
stations = [
    '70:ee:50:3b:f5:64', # Venta del Olivar
    '70:ee:50:74:29:4c', # Cuarte de Huerva, Urbanización de Amelia
    '70:ee:50:7a:d1:ce', # Cuarte de Huerva, Urbanización de Amelia
    '70:ee:50:84:81:46', # Murallas de Santa Fe
    '70:ee:50:3f:63:68', # Santa Isabel
    '70:ee:50:2b:58:c2' # Villamayor de Gállego
]

# %% [markdown]
# ### Generate shapefile

# %%
import geopandas as gpd
from shapely.geometry import Point

# %%
# Create a GeoDataFrame
geometry = [Point(xy) for xy in zip(stations['lon'], stations['lat'])]
gdf = gpd.GeoDataFrame(stations, geometry=geometry)

# Set CRS and save
filename = 'netatmo_stations.shp'
gdf.set_crs(epsg=4326, inplace=True)
gdf = gdf.to_crs('EPSG:25830')
gdf.to_file(filename)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 # Create a GeoDataFrame
# ----> 2 geometry = [Point(xy) for xy in zip(stations['lon'], stations['lat'])]
#       3 gdf = gpd.GeoDataFrame(stations, geometry=geometry)
#       5 # Set CRS and save
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# ### Locate stations

# %%
station_id = '70:ee:50:7a:8d:66'

row = stations[stations['device_id'] == station_id]

# Extract lon and lat
lon, lat = row[['lon', 'lat']].values[0]

location_map = folium.Map(location=zgz_coords, zoom_start=13)
folium.Marker([lat, lon], popup=station_id).add_to(location_map)
location_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0bc38e584a3bcdf791a6e32603a1b994 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0bc38e584a3bcdf791a6e32603a1b994&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0bc38e584a3bcdf791a6e32603a1b994 = L.map(
#                 &quot;map_0bc38e584a3bcdf791a6e32603a1b994&quot;,
#                 {
#                     center: [41.653858, -0.876258],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_41e2c2abb5266ffcad756090397e95dd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0bc38e584a3bcdf791a6e32603a1b994);
#
#
#             var marker_4bbe0ed3e889b3267a2f5ca937dde30f = L.marker(
#                 [41.636124, -0.7481712],
#                 {}
#             ).addTo(map_0bc38e584a3bcdf791a6e32603a1b994);
#
#
#         var popup_0cd2de32c2339aa34790e0af6ac8fcac = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ca1d24f6159eaf6ed73a25a9d2b7d2d9 = $(`&lt;div id=&quot;html_ca1d24f6159eaf6ed73a25a9d2b7d2d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;70:ee:50:7a:8d:66&lt;/div&gt;`)[0];
#                 popup_0cd2de32c2339aa34790e0af6ac8fcac.setContent(html_ca1d24f6159eaf6ed73a25a9d2b7d2d9);
#
#
#
#         marker_4bbe0ed3e889b3267a2f5ca937dde30f.bindPopup(popup_0cd2de32c2339aa34790e0af6ac8fcac)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
